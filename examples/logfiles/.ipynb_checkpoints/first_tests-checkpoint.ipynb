# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Combinations of hypernet_dim, hypernet_n_layers, and corresponding number of parameters:
# (7,2,646),
# (6,3,600),
# (7,3,702),
# (6,4,642),
# (6,5,684),
# (5,6,592),
# (5,7,622),
# (5,8,652).

# %% [markdown]
# Varying end time T = (1, 10, 100)

# %%
index = range(8)

train_t1 = [0.8281, 0.8125, 0.7266, 0.8398, 0.7930, 0.7773, 0.8320, 0.7969]
test_t1 = [0.7625, 0.6750, 0.7500, 0.7500, 0.7125, 0.7250, 0.7250, 0.7375]

train_t2 = [0.9258, 0.8281, 0.9492, 0.8789, 0.8281, 0.8477, 0.8906, 0.8984]
test_t2 = [0.8500, 0.7625, 0.7375, 0.8125, 0.7875, 0.8125, 0.8375, 0.8375]

train_t3 = [0.8242, 0.8320, 0.8125, 0.8633, 0.7891, 0.8594, 0.8359, 0.8789]
test_t3 = [0.7875, 0.7625, 0.7375, 0.8250, 0.7250, 0.8000, 0.7750, 0.7250]

plt.plot(index, train_t1, label='train_t1')
plt.plot(index, test_t1, label='test_t1')

plt.plot(index, train_t2, label='train_t2')
plt.plot(index, test_t2, label='test_t2')

plt.plot(index, train_t3, label='train_t3')
plt.plot(index, test_t3, label='test_t3')

plt.legend(loc=4, fontsize="small")
